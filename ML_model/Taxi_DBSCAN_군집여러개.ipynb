# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import folium
from datetime import datetime
import matplotlib.pyplot as plt
from IPython.display import display
import random

# %%
# 데이터 로드 및 전처리
df = pd.read_csv('train_taxi_tims.csv', encoding='euc-kr')
df = df.iloc[45:]  # 결측치 제거
df['승차시간'] = pd.to_datetime(df['승차시간'])
df['월'] = df['승차시간'].dt.month
df['요일'] = df['승차시간'].dt.day_name()
df['시간'] = df['승차시간'].dt.hour

# 요일 매핑
day_mapping = {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
df['요일_숫자'] = df['요일'].map(day_mapping)

# %%
def find_optimal_eps(coords, min_pts):
    neigh = NearestNeighbors(n_neighbors=min_pts)
    nbrs = neigh.fit(coords)
    distances, indices = nbrs.kneighbors(coords)
    distances = np.sort(distances, axis=0)
    distances = distances[:, 1]
    plt.figure(figsize=(10, 5))
    plt.plot(distances)
    plt.ylabel("Distance")
    plt.xlabel("Points")
    plt.title("K-distance Graph")
    plt.show()
    return distances

# %%
def generate_colors(n):
    return ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(n)]

# %%
def recommend_location(month, day, hour):
    # 입력된 조건에 맞는 데이터 필터링
    filtered_df = df[(df['월'] == month) & (df['요일_숫자'] == day_mapping[day]) & (df['시간'] == hour)]

    if filtered_df.empty:
        return "해당 조건에 맞는 데이터가 없습니다."

    # DBSCAN 적용
    coords = filtered_df[['승차X좌표', '승차Y좌표']].values
    min_pts = max(2, len(coords) // 25)  # minPts는 최소 2 또는 데이터 개수의 1/10 ########################################### <<<<<<<<<<-------

    # 최적의 epsilon 찾기
    distances = find_optimal_eps(coords, min_pts)
    epsilon = np.percentile(distances, 90)  # 90th percentile as epsilon

    db = DBSCAN(eps=epsilon, min_samples=min_pts).fit(coords)

    # 클러스터 레이블 및 개수 확인
    labels = db.labels_
    n_clusters = len(set(labels)) - (1 if -1 in labels else 0)

    if n_clusters == 0:
        return f"클러스터링 결과가 없습니다. 현재 ε 값: {epsilon}"

    # 색상 생성
    colors = generate_colors(n_clusters)

    # 지도 생성
    center = np.mean(coords, axis=0)
    m = folium.Map(location=[center[1], center[0]], zoom_start=13)

    # 각 클러스터별로 포인트 표시
    for i, (label, color) in enumerate(zip(set(labels) - {-1}, colors)):
        cluster_points = coords[labels == label]
        for point in cluster_points:
            folium.CircleMarker([point[1], point[0]], radius=5, color=color, fill=True).add_to(m)

        # 클러스터 중심점 계산 및 표시
        cluster_center = np.mean(cluster_points, axis=0)
        folium.Marker([cluster_center[1], cluster_center[0]],
                      icon=folium.Icon(color='green', icon='info-sign'),
                      popup=f'Cluster {i+1}').add_to(m)

    # 노이즈 포인트 표시 (회색)
    noise_points = coords[labels == -1]
    for point in noise_points:
        folium.CircleMarker([point[1], point[0]], radius=3, color='gray', fill=True).add_to(m)

    return m, epsilon, n_clusters

# %%
# 사용 예시
month = 10
day = 'Monday'
hour = 14

result = recommend_location(month, day, hour)

if isinstance(result, tuple):
    map_obj, epsilon, n_clusters = result
    display(map_obj)
    print(f"사용된 ε 값: {epsilon}")
    print(f"클러스터 수: {n_clusters}")
else:
    print(result)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5abc982f026436e9e4904e7fc739c79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5abc982f026436e9e4904e7fc739c79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5abc982f026436e9e4904e7fc739c79 = L.map(
#                 &quot;map_e5abc982f026436e9e4904e7fc739c79&quot;,
#                 {
#                     center: [36.22253703005094, 126.96163837079797],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a835f3e79504bfb8195365787925ade = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a835f3e79504bfb8195365787925ade.addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_86550bef0394b7d3a3d13da1d84b97ca = L.circleMarker(
#                 [36.33242035, 127.4361574],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1A3FDC&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1A3FDC&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_4df5faebaf7e39f3fc2b9b16ff70a8b5 = L.circleMarker(
#                 [36.33190369, 127.4328767],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1A3FDC&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1A3FDC&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_29982ce3de309b4b03b99e1f13c3d7c1 = L.circleMarker(
#                 [36.33190369, 127.4328339],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1A3FDC&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1A3FDC&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_a9cfebb5404c0227c8e89519532e88ea = L.circleMarker(
#                 [36.32906738, 127.4269453],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1A3FDC&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1A3FDC&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_b47f9be0fd5e0fb9491380de862291dc = L.circleMarker(
#                 [36.32975633, 127.4334266],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1A3FDC&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1A3FDC&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_2fb154c8b9ab6999f2061a38b4ad48f0 = L.circleMarker(
#                 [36.33401212, 127.4313851],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1A3FDC&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1A3FDC&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e5abc982f026436e9e4904e7fc739c79);
#
#
#             var circle_marker_791fc0fba00f3ae266feffa42b3779b2 = L.circleMarker(
# 사용된 ε 값: 0.004254355383172958
# 클러스터 수: 2
